# %%
# import libraries
import pandas as pd
import numpy as np
import time

# import csv file
filename = 'Mental Health in Tech survey.csv'
df = pd.read_csv(filename)

df
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
gender = df[['wellness_program']]
df[['wellness_program']].value_counts()
wellnessno = len(df[(df['wellness_program']=='No')])
wellnessyes = len(df[(df['wellness_program']=='Yes')])
wellnessdk = len(df[(df['wellness_program']=="Don't know")])

# %%
import matplotlib.pyplot as plt

# mentalvsphysical: Has your employer ever discussed mental health as part of an employee wellness program?
response = ['No','Yes',"Don't know"]
counts = [wellnessno,wellnessyes,wellnessdk]

# Figure Size 
fig, ax1 = plt.subplots(figsize =(30, 15))

# creating bar chart
ax1.bar(response,counts,color=['royalblue','grey','grey'])

# label title
ax1.set_title('Has Your Employer Discussed Mental Health as Part of an Employee Wellness Program?', loc='center',fontsize=30)

# label x-axis
ax1.set_xlabel('Response',fontsize=25)

# label y-axis
ax1.set_ylabel('Number of Responses',fontsize=25)

# set fontsize on x-axis and y-axis ticks
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# set limit on y-axis
#ax1.set_ylim(0,1)
for bar in ax1:
    yval = bar.get_height()
    plt.text(bar.get_x(), yval + .005, yval)
# show bar chart
#plt.savefig('employeewellnessprogram.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-280-3d68032aa537> in <module>
#      26 # set limit on y-axis
#      27 #ax1.set_ylim(0,1)
# ---> 28 for bar in ax1:
#      29     yval = bar.get_height()
#      30     plt.text(bar.get_x(), yval + .005, yval)
#
# TypeError: 'AxesSubplot' object is not iterable

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['No', 'Yes']
t1 = [benefits1, nobenefits1]
t2 = [benefits2, nobenefits2]


x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, t1, width, label='Yes',color = 'seagreen')
rects2 = ax.bar(x + width/2, t2, width, label='No',color = 'firebrick')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Responses')
ax.set_title('Does your Employer Provide Mental Health Benefits?')
ax.set_ylim([0,330])
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)


plt.savefig('options.png')
plt.show()

# %%
coun = df[['Country']]
c = df[['Country']].value_counts()
# Out:
# Country
# United States             751
# United Kingdom            185
# Canada                     72
# Germany                    45
# Ireland                    27
# Netherlands                27
# Australia                  21
# France                     13
# India                      10
# New Zealand                 8
# Poland                      7
# Italy                       7
# Sweden                      7
# Switzerland                 7
# Belgium                     6
# Brazil                      6
# South Africa                6
# Israel                      5
# Singapore                   4
# Bulgaria                    4
# Russia                      3
# Austria                     3
# Finland                     3
# Mexico                      3
# Greece                      2
# Croatia                     2
# Portugal                    2
# Denmark                     2
# Colombia                    2
# Costa Rica                  1
# ...

# %%
work = df[['work_interfere']]
df[['work_interfere']].value_counts()
# Out:
# work_interfere
# Sometimes         465
# Never             213
# Rarely            173
# Often             144
# dtype: int64

# %%
benefit = df[['seek_help']]
df[['seek_help']].value_counts()
# Out:
# seek_help
# No            646
# Don't know    363
# Yes           250
# dtype: int64

# %%
first_df = len(df[(df['seek_help']=='No')&(df['treatment']=='Yes')])
second_df = len(df[(df['seek_help']=='Yes')&(df['treatment']=='Yes')])
#first_df
#seekhelpyes = len(df[(df['seek_help']=='Yes')])
#seekhelpno = len(df[(df['seek_help']=='No')])
#treatmentyes = len(df['treatment']=='Yes')
#treatmentno = len(df['treatment']=='No')
#lengthfirst = len(df[(df['seek_help']=='No')&(df['treatment']=='Yes')])
#treatmentyes
first_df
# Out:
# 323

# %%
import matplotlib.pyplot as plt

# mentalvsphysical: Do you feel that your employer takes mental health as seriously as physical health?
response = ['Yes','No']
counts = [first_df,second_df]

# Figure Size 
fig, ax1 = plt.subplots(figsize =(30, 15))

# creating bar chart
ax1.bar(response,counts,color=['magenta','grey','grey'])

# label title
ax1.set_title('Are Resources Provided for Those Who Sought Treatment?', loc='center',fontsize=25)

# label x-axis
ax1.set_xlabel('Response',fontsize=20)

# label y-axis
ax1.set_ylabel('Number of Responses',fontsize=20)

# set fontsize on x-axis and y-axis ticks
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)

# set limit on y-axis
#ax1.set_ylim(0,1)

# show bar chart
plt.show()

# %%
import matplotlib.pyplot as plt

# sought treatment and employer does not provide resources
import numpy as np

data = [[30, 25, 50],
[40, 23, 51],
[35, 22, 45]]
X = np.arange(3)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, data[0], color = 'b', width = 0.25)
ax.bar(X + 0.25, data[1], color = 'g', width = 0.25)
ax.bar(X + 0.50, data[2], color = 'r', width = 0.25)
# Out:
# <BarContainer object of 3 artists>

# %%
b = df[['mental_vs_physical']]
c = df[['mental_vs_physical']].value_counts()
dk = len(df[(df['mental_vs_physical']=="Don't know")])
y = len(df[(df['mental_vs_physical']=="Yes")])
n = len(df[(df['mental_vs_physical']=="No")])
dk
# Out:
# 576

# %%
import matplotlib.pyplot as plt

# mentalvsphysical: Do you feel that your employer takes mental health as seriously as physical health?
response = ["Don't know",'Yes','No']
counts = [dk,y,n]

# Figure Size 
fig, ax1 = plt.subplots(figsize =(30, 15))

# creating bar chart
ax1.bar(response,counts,color=['gold','grey','grey'])

# label title
ax1.set_title('Does Employer Take Mental Health as Seriously as Physical Health?', loc='center',fontsize=25)

# label x-axis
ax1.set_xlabel('Response',fontsize=20)

# label y-axis
ax1.set_ylabel('Number of Responses',fontsize=20)

# set fontsize on x-axis and y-axis ticks
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)

# set limit on y-axis
#ax1.set_ylim(0,1)

# show bar chart
plt.savefig('mentalvsphysical.jpg')
plt.show()

# %%
leaving = df[['leave']]
d = df[['leave']].value_counts()
d
# Out:
# leave
# Don't know            563
# Somewhat easy         266
# Very easy             206
# Somewhat difficult    126
# Very difficult         98
# dtype: int64

# %%
second_df = df[(df['treatment']=='Yes')&(df['leave']=="Don't know")]
secondlength = len(df[(df['treatment']=='Yes')&(df['leave']=="Don't know")])
second_df
# Out:
#                 Timestamp  Age  Gender        Country state self_employed  \
# 10    2014-08-27 11:32:44   31    Male  United States    OH           NaN
# 17    2014-08-27 11:34:37   32    Male  United States    TN           NaN
# 22    2014-08-27 11:35:48   46    Male  United States    MA            No
# 23    2014-08-27 11:36:24   41    Male  United States    IA            No
# 24    2014-08-27 11:36:48   33    male  United States    CA            No
# ...                   ...  ...     ...            ...   ...           ...
# 1245  2015-05-06 10:14:50   22    Male      Australia   NaN            No
# 1248  2015-06-25 12:24:31   41  Female  United States    WA            No
# 1250  2015-07-27 23:25:34   30    Male  United States    CA           Yes
# 1252  2015-08-20 16:52:09   29    male  United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male  United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...       leave  \
# ...

# %%
p = df[['work_interfere']].value_counts()
p
# Out:
# work_interfere
# Sometimes         465
# Never             213
# Rarely            173
# Often             144
# dtype: int64

# %%
sometimes = len(df[(df['treatment']=='Yes')&(df['work_interfere']=="Sometimes")])
never = len(df[(df['treatment']=='Yes')&(df['work_interfere']=="Never")])
rarely = len(df[(df['treatment']=='Yes')&(df['work_interfere']=="Rarely")])
often = len(df[(df['treatment']=='Yes')&(df['work_interfere']=="Often")])
sometimes
# Out:
# 358

# %%
import matplotlib.pyplot as plt

# categories: age and pclass
response = ['Sometimes','Never','Rarely','Often']
counts = [sometimes,never,rarely,often]

# Figure Size 
fig, ax1 = plt.subplots(figsize =(30, 15))

# creating bar chart
ax1.bar(response,counts,color=['firebrick','grey','grey','grey'])

# label title
ax1.set_title('Does Mental Health Interfere with Your Work?', loc='center',fontsize=30)

# label x-axis
ax1.set_xlabel('Responses from Those Who Sought Treatment',fontsize=25)

# label y-axis
ax1.set_ylabel('Number of Responses',fontsize=25)

# set fontsize on x-axis and y-axis ticks
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)


# set limit on y-axis
#ax1.set_ylim(0,1)

# show bar chart
#plt.savefig('mentalhealthinterfere.png')
plt.show()

# %%
coworkers = df[['coworkers']]
z = df[['coworkers']].value_counts()
dd = len(df['coworkers'])
dd
z
# Out:
# coworkers
# Some of them    774
# No              260
# Yes             225
# dtype: int64

# %%
obs = df[['supervisor']].value_counts()
o = len(df[(df['supervisor']=='Yes')])
obs
# Out:
# supervisor
# Yes             516
# No              393
# Some of them    350
# dtype: int64

# %%
genders = df[['Gender']].value_counts()
genders
# Out:
# Gender
# Male                                              615
# male                                              206
# Female                                            121
# M                                                 116
# female                                             62
# F                                                  38
# m                                                  34
# f                                                  15
# Make                                                4
# Woman                                               3
# Male                                                3
# Female (trans)                                      2
# Cis Male                                            2
# Female                                              2
# Man                                                 2
# Guy (-ish) ^_^                                      1
# Mal                                                 1
# ...

# %%
df['care_options'].value_counts()
# Out:
# No          501
# Yes         444
# Not sure    314
# Name: care_options, dtype: int64

# %%
treatment1 = len(df[(df['treatment']=='Yes')&(df['care_options']=='Yes')])
treatment2 = len(df[(df['treatment']=='Yes')&(df['care_options']=='No')])


notreatment1 = len(df[(df['treatment']=='No')&(df['care_options']=='Yes')])
notreatment2 = len(df[(df['treatment']=='No')&(df['care_options']=='No')])

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Treatment', 'No Treatment']
t1 = [treatment1, notreatment1]
t2 = [treatment2, notreatment2]


x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, t1, width, label='Yes',color = 'seagreen')
rects2 = ax.bar(x + width/2, t2, width, label='No',color = 'firebrick')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Responses')
ax.set_title('Do You Know the Mental Health Care Options your Employer Provides?')
ax.set_ylim([0,330])
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

plt.legend(loc = 'best', bbox_to_anchor = (1,0.5))
plt.savefig('options.png',bbox_inches='tight')
plt.show()

# %%
df['benefits'].value_counts()
# Out:
# Yes           477
# Don't know    408
# No            374
# Name: benefits, dtype: int64

# %%
benefits1 = len(df[(df['treatment']=='Yes')&(df['benefits']=='Yes')])
benefits2 = len(df[(df['treatment']=='Yes')&(df['benefits']=='No')])


nobenefits1 = len(df[(df['treatment']=='No')&(df['benefits']=='Yes')])
nobenefits2 = len(df[(df['treatment']=='No')&(df['benefits']=='No')])
# Out:
# 193

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Treatment', 'No Treatment']
t1 = [benefits1, nobenefits1]
t2 = [benefits2, nobenefits2]


x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, t1, width, label='Yes',color = 'seagreen')
rects2 = ax.bar(x + width/2, t2, width, label='No',color = 'firebrick')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Responses')
ax.set_title('Does your Employer Provide Mental Health Benefits?')
ax.set_ylim([0,330])
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

plt.legend(loc = 'best', bbox_to_anchor = (1,0.5))
plt.savefig('benefits.png',bbox_inches='tight')
plt.show()

# %%
df['work_interfere'].value_counts()
#interfere1 = len(df[(df['treatment']=='Yes')&(df['work_interfere']=='Often')])
#interfere1
# Out:
# Sometimes    465
# Never        213
# Rarely       173
# Often        144
# Name: work_interfere, dtype: int64

# %%
interfere1= len(df[(df['benefits']=='Yes')&(df['work_interfere']=='Often')])
interfere2 = len(df[(df['benefits']=='Yes')&(df['work_interfere']=='Never')])

nointerfere1 = len(df[(df['benefits']=='No')&(df['work_interfere']=='Often')])
nointerfere2 = len(df[(df['benefits']=='No')&(df['work_interfere']=='Never')])

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['Treatment', 'No Treatment']
t1 = [interfere1, nointerfere1]
t2 = [interfere2, nointerfere2]


x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, t1, width, label='Yes',color = 'seagreen')
rects2 = ax.bar(x + width/2, t2, width, label='No',color = 'firebrick')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Responses')
ax.set_title('Does Mental Health Interfere with Your Work?')
ax.set_ylim([0,85])
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

plt.legend(loc = 'best', bbox_to_anchor = (1,0.5))
plt.savefig('treated.png',bbox_inches='tight')
plt.show()
